# %% [markdown]
# # Notebook 3: k-NN Baseline
#
# Este notebook construye un baseline colaborativo utilizando:
#
# - **User-based k-NN**
# - **Item-based k-NN**
#
# Se evalúa con las métricas:
#
# - HitRate@K
# - Recall@K
# - NDCG@K
#
# Este baseline servirá para comparar métodos de reducción de datos y eficiencia.

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
from surprise import accuracy
from tqdm import tqdm
from pathlib import Path

# %% [markdown]
# # Carga de datos procesados

# %%
data_path = Path("../data/processed")

train = pd.read_csv(data_path / "train.csv")
test = pd.read_csv(data_path / "test.csv")
movies = pd.read_csv(data_path / "movies.csv")

# %% [markdown]
# # Preparación del dataset para Surprise

# %%
reader = Reader(rating_scale=(1, 5))
train_data = Dataset.load_from_df(train[['userId','movieId','rating']], reader).build_full_trainset()
testset = list(zip(test['userId'], test['movieId'], test['rating']))

# %% [markdown]
# # Configuración de k-NN
#
# - Usaremos similitud coseno
# - User-based y Item-based
# - K vecinos = 40

# %%
sim_options_user = {'name': 'cosine', 'user_based': True}
sim_options_item = {'name': 'cosine', 'user_based': False}

knn_user = KNNBasic(k=40, sim_options=sim_options_user)
knn_item = KNNBasic(k=40, sim_options=sim_options_item)

# %% [markdown]
# # Entrenamiento

# %%
print("Entrenando UserKNN...")
knn_user.fit(train_data)
print("Entrenando ItemKNN...")
knn_item.fit(train_data)
# Out:
# Entrenando UserKNN...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Entrenando ItemKNN...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# # Evaluación Leave-One-Out
# Se predice la puntuación del ítem de test para cada usuario.

# %%
def hit_rate(ranklist, gt_item):
    return 1.0 if gt_item in ranklist else 0.0

def ndcg(ranklist, gt_item):
    if gt_item in ranklist:
        idx = ranklist.index(gt_item)
        return 1 / np.log2(idx + 2)
    return 0.0

def recall(ranklist, gt_item):
    return 1.0 if gt_item in ranklist else 0.0

Ks = [5, 10, 20, 50]

# %%
user_train_items = train.groupby('userId')['movieId'].apply(set).to_dict()
all_items = set(movies['movieId'].unique())

# %% [markdown]
# # Evaluación top-K

# %%
results_user = {k: {'hit': [], 'ndcg': [], 'recall': []} for k in Ks}

for _, row in tqdm(test.iterrows(), total=len(test)):
    user, gt_item = row['userId'], row['movieId']
    seen = user_train_items.get(user, set())
    
    # Predecir puntuaciones para todos los ítems no vistos
    candidates = [i for i in all_items if i not in seen]
    predictions = [knn_user.predict(user, i).est for i in candidates]
    
    top_items = [x for _, x in sorted(zip(predictions, candidates), reverse=True)]
    
    for k in Ks:
        top_k = top_items[:k]
        results_user[k]['hit'].append(hit_rate(top_k, gt_item))
        results_user[k]['recall'].append(recall(top_k, gt_item))
        results_user[k]['ndcg'].append(ndcg(top_k, gt_item))
# Out:
# 100%|██████████| 6040/6040 [1:10:36<00:00,  1.43it/s]

# %%
results_item = {k: {'hit': [], 'ndcg': [], 'recall': []} for k in Ks}

for _, row in tqdm(test.iterrows(), total=len(test)):
    user, gt_item = row['userId'], row['movieId']
    seen = user_train_items.get(user, set())
    
    candidates = [i for i in all_items if i not in seen]
    predictions = [knn_item.predict(user, i).est for i in candidates]
    
    top_items = [x for _, x in sorted(zip(predictions, candidates), reverse=True)]
    
    for k in Ks:
        top_k = top_items[:k]
        results_item[k]['hit'].append(hit_rate(top_k, gt_item))
        results_item[k]['recall'].append(recall(top_k, gt_item))
        results_item[k]['ndcg'].append(ndcg(top_k, gt_item))
# Out:
# 100%|██████████| 6040/6040 [37:29<00:00,  2.68it/s]

# %%
summary_user = []
summary_item = []

for k in Ks:
    summary_user.append({
        'K': k,
        'HitRate': np.mean(results_user[k]['hit']),
        'Recall': np.mean(results_user[k]['recall']),
        'NDCG': np.mean(results_user[k]['ndcg']),
    })
    
    summary_item.append({
        'K': k,
        'HitRate': np.mean(results_item[k]['hit']),
        'Recall': np.mean(results_item[k]['recall']),
        'NDCG': np.mean(results_item[k]['ndcg']),
    })

df_user = pd.DataFrame(summary_user)
df_item = pd.DataFrame(summary_item)

print("UserKNN Results")
display(df_user)

print("ItemKNN Results")
display(df_item)
# Out:
# UserKNN Results
#     K   HitRate    Recall      NDCG
# 0   5  0.000000  0.000000  0.000000
# 1  10  0.000497  0.000497  0.000146
# 2  20  0.011258  0.011258  0.002792
# 3  50  0.031623  0.031623  0.006761
# ItemKNN Results
#     K   HitRate    Recall      NDCG
# 0   5  0.000828  0.000828  0.000420
# 1  10  0.004139  0.004139  0.001466
# 2  20  0.012086  0.012086  0.003436
# 3  50  0.034603  0.034603  0.007847

# %%
df_user.to_csv(data_path / "userknn_results.csv", index=False)
df_item.to_csv(data_path / "itemknn_results.csv", index=False)
print("Resultados guardados en data/processed/")
# Out:
# Resultados guardados en data/processed/

# %% [markdown]
# ---
# #  Variantes energéticas con diferentes k
#
# ## Objetivo:
# Evaluar el impacto del número de vecinos (k) en:
# - **Precisión predictiva** (RMSE, MAE)
# - **Consumo energético** (emisiones CO₂)
#
# ## Configuración:
# - **k vecinos**: 20, 30, 40 (menor k = menos cómputo)
# - **Fracciones del dataset**: 25%, 50%, 75%
# - **Modelo**: ItemKNN (basado en ítems)
#
# ## Hipótesis:
# - Menor k → Menos cálculos de similitud → Menor consumo energético
# - ¿Afecta significativamente la precisión?

# %%
from codecarbon import EmissionsTracker
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Experimentos con diferentes valores de k

# %%
results_knn_variants = []

k_values = [20, 30, 40]
fractions = [25, 50, 75]

print("="*70)
print("EXPERIMENTOS: Variantes energéticas ItemKNN")
print("="*70)
print(f"Total experimentos: {len(k_values) * len(fractions)}")
print()

experiment_count = 0

for k_neighbors in k_values:
    for fraction in fractions:
        experiment_count += 1
        
        print(f"\n{'='*70}")
        print(f"EXPERIMENTO {experiment_count}/{len(k_values)*len(fractions)}")
        print(f"ItemKNN: k={k_neighbors}, fracción={fraction}%")
        print('='*70)
        
        train_file = data_path / "subsampled_informed" / f"ratings_top_items_{fraction}.csv"
        
        if not train_file.exists():
            print(f"  ADVERTENCIA: {train_file} no existe")
            continue
        
        train_frac = pd.read_csv(train_file)
        print(f"Dataset cargado: {len(train_frac)} ratings")
        
        reader = Reader(rating_scale=(1, 5))
        data = Dataset.load_from_df(
            train_frac[['userId','movieId','rating']], reader
        )
        trainset = data.build_full_trainset()
        
        model = KNNBasic(
            k=k_neighbors,
            sim_options={'name': 'cosine', 'user_based': False},
            verbose=False
        )
        
        tracker = EmissionsTracker(
            project_name=f"ItemKNN_k{k_neighbors}_f{fraction}",
            output_dir="../results",
            log_level="error"
        )
        tracker.start()
        
        print("Entrenando modelo...")
        model.fit(trainset)
        
        print("Generando predicciones...")
        testset_frac = list(zip(test['userId'], test['movieId'], test['rating']))
        predictions = model.test(testset_frac)
        
        emissions = tracker.stop()
        
        actuals = [pred.r_ui for pred in predictions]
        preds = [pred.est for pred in predictions]
        
        rmse = np.sqrt(mean_squared_error(actuals, preds))
        mae = mean_absolute_error(actuals, preds)
        
        results_knn_variants.append({
            'method': f'ItemKNN_k{k_neighbors}',
            'k_neighbors': k_neighbors,
            'fraction': fraction,
            'rmse': rmse,
            'mae': mae,
            'emissions_kg': emissions,
            'train_size': len(train_frac)
        })
        
        print(f"\n RESULTADOS:")
        print(f"   RMSE: {rmse:.4f}")
        print(f"   MAE:  {mae:.4f}")
        print(f"   CO2:  {emissions:.6f} kg ({emissions*1000:.3f} g)")

print(f"\n{'='*70}")
print(f"EXPERIMENTOS COMPLETADOS: {len(results_knn_variants)}/{len(k_values)*len(fractions)}")
print('='*70)
# Out:
# ...
# EXPERIMENTOS: Variantes energéticas ItemKNN
# ...
# Total experimentos: 9
#
#
# ...
# EXPERIMENTO 1/9
# ItemKNN: k=20, fracción=25%
# ...
# Dataset cargado: 723075 ratings
# [codecarbon WARNING @ 09:38:54] Multiple instances of codecarbon are allowed to run at the same time.
# Entrenando modelo...
# Generando predicciones...
#
# ✅ RESULTADOS:
#    RMSE: 1.1006
#    MAE:  0.8590
#    CO2:  0.000127 kg (0.127 g)
#
# ...
# EXPERIMENTO 2/9
# ItemKNN: k=20, fracción=50%
# ...
# Dataset cargado: 923889 ratings
# Entrenando modelo...
# Generando predicciones...
#
# ✅ RESULTADOS:
#    RMSE: 1.0239
#    MAE:  0.7967
#    CO2:  0.000239 kg (0.239 g)
#
# ...
# EXPERIMENTO 3/9
# ItemKNN: k=20, fracción=75%
# ...
# Dataset cargado: 988678 ratings
# Entrenando modelo...
# Generando predicciones...
#
# ✅ RESULTADOS:
#    RMSE: 0.9787
#    MAE:  0.7614
#    CO2:  0.000300 kg (0.300 g)
#
# ...
# EXPERIMENTO 4/9
# ItemKNN: k=30, fracción=25%
# ...
# Dataset cargado: 723075 ratings
# Entrenando modelo...
# Generando predicciones...
#
# ✅ RESULTADOS:
# ...

# %% [markdown]
# ## Guardar resultados de variantes energéticas

# %%
if len(results_knn_variants) > 0:
    df_variants = pd.DataFrame(results_knn_variants)
    df_variants = df_variants.sort_values(['k_neighbors', 'fraction'])
    
    output_file = Path("../results/knn_energy_variants.csv")
    df_variants.to_csv(output_file, index=False)
    
    print(f"\n Resultados guardados en: {output_file}")
    print(f"\nResumen:")
    print(df_variants[['method', 'k_neighbors', 'fraction', 'rmse', 'mae', 'emissions_kg']].to_string(index=False))
else:
    print("\n  No hay resultados para guardar")
# Out:
# ✅ Resultados guardados en: ..\results\knn_energy_variants.csv
#
# Resumen:
#      method  k_neighbors  fraction     rmse      mae  emissions_kg
# ItemKNN_k20           20        25 1.100645 0.858981      0.000127
# ItemKNN_k20           20        50 1.023932 0.796730      0.000239
# ItemKNN_k20           20        75 0.978720 0.761431      0.000300
# ItemKNN_k30           30        25 1.112200 0.873912      0.000125
# ItemKNN_k30           30        50 1.049448 0.822302      0.000247
# ItemKNN_k30           30        75 1.010429 0.791093      0.000299
# ItemKNN_k40           40        25 1.118785 0.881457      0.000134
# ItemKNN_k40           40        50 1.061069 0.834842      0.000237
# ItemKNN_k40           40        75 1.028392 0.808957      0.000301

# %% [markdown]
# ## Análisis preliminar: impacto de k

# %%
if len(results_knn_variants) > 0:
    import matplotlib.pyplot as plt
    
    df_variants = pd.DataFrame(results_knn_variants)
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    for fraction in df_variants['fraction'].unique():
        data = df_variants[df_variants['fraction'] == fraction]
        axes[0].plot(data['k_neighbors'], data['rmse'], marker='o', label=f'{fraction}%')
    
    axes[0].set_xlabel('Número de vecinos (k)')
    axes[0].set_ylabel('RMSE')
    axes[0].set_title('Impacto de k en precisión')
    axes[0].legend(title='Fracción')
    axes[0].grid(alpha=0.3)
    
    for fraction in df_variants['fraction'].unique():
        data = df_variants[df_variants['fraction'] == fraction]
        axes[1].plot(data['k_neighbors'], data['emissions_kg']*1000, marker='o', label=f'{fraction}%')
    
    axes[1].set_xlabel('Número de vecinos (k)')
    axes[1].set_ylabel('Emisiones CO₂ (g)')
    axes[1].set_title('Impacto de k en sostenibilidad')
    axes[1].legend(title='Fracción')
    axes[1].grid(alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('../results/knn_k_impact.png', dpi=150, bbox_inches='tight')
    print("\n Gráfico guardado en results/knn_k_impact.png")
    plt.show()
else:
    print("No hay suficientes datos para análisis")
# Out:
# ✅ Gráfico guardado en results/knn_k_impact.png
